# %% [markdown]
# # TensorFlow Day2

# %%
import tensorflow as tf

# %%
# X and Y data
x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# hypothesis = Wx + b

hypothesis = W * x_train + b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8c63f31052f6> in <module>
#       3 y_train = [1,2,3]
#       4
# ----> 5 W = tf.Variable(tf.random_normal([1]), name='weight')
#       6 b = tf.Variable(tf.random_normal([1]), name='bias')
#       7
#
# AttributeError: module 'tensorflow' has no attribute 'random_normal'

# %%
# cost / loss funciton
# reduce_mean -> 평균을 내주는 함수
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
# 오차 최소화 ( Minimize )

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()

# Initializes global variables(w,b) in the graph.
sess.run(tf.global_variables_initializer())

# %%
# run train

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 3.1662252 [1.0930796] [1.5916061]
# 20 0.24644299 [0.51860684] [1.266019]
# 40 0.1999855 [0.4869462] [1.1826409]
# 60 0.18141393 [0.5058888] [1.1247874]
# 80 0.16476111 [0.52861804] [1.0717101]
# 100 0.14963867 [0.5507244] [1.0213232]
# 120 0.13590431 [0.5718342] [0.973323]
# 140 0.12343044 [0.59195596] [0.9275802]
# 160 0.11210147 [0.61113244] [0.8839873]
# 180 0.1018124 [0.62940776] [0.8424432]
# 200 0.092467666 [0.6468242] [0.8028515]
# 220 0.08398059 [0.66342217] [0.7651203]
# 240 0.076272525 [0.6792401] [0.72916245]
# 260 0.06927193 [0.69431466] [0.69489455]
# 280 0.06291387 [0.7086808] [0.6622371]
# 300 0.057139356 [0.7223717] [0.6311143]
# 320 0.051894948 [0.73541915] [0.6014544]
# 340 0.047131766 [0.7478535] [0.5731882]
# 360 0.04280584 [0.75970346] [0.5462505]
# 380 0.03887697 [0.7709965] [0.5205788]
# 400 0.03530867 [0.78175884] [0.49611348]
# 420 0.032067914 [0.7920154] [0.47279796]
# 440 0.029124582 [0.8017898] [0.45057824]
# 460 0.026451422 [0.8111051] [0.42940268]
# 480 0.024023598 [0.81998235] [0.4092224]
# 500 0.021818632 [0.8284426] [0.38999045]
# 520 0.019816004 [0.8365052] [0.3716623]
# 540 0.01799722 [0.84418875] [0.35419554]
# 560 0.016345372 [0.85151136] [0.33754963]
# 580 0.014845123 [0.85848975] [0.32168606]
# 600 0.013482592 [0.8651402] [0.306568]
# 620 0.012245081 [0.87147814] [0.29216042]
# 640 0.011121184 [0.8775183] [0.27842996]
# 660 0.010100446 [0.88327444] [0.26534468]
# 680 0.009173378 [0.8887602] [0.25287446]
# 700 0.008331412 [0.893988] [0.24099022]
# 720 0.0075667165 [0.8989701] [0.2296646]
# 740 0.0068722144 [0.90371823] [0.21887119]
# 760 0.0062414543 [0.9082431] [0.20858504]
# 780 0.005668584 [0.91255534] [0.19878228]
# 800 0.0051482944 [0.9166649] [0.1894402]
# 820 0.0046757646 [0.9205814] [0.1805372]
# 840 0.0042466056 [0.9243138] [0.17205262]
# 860 0.0038568347 [0.9278707] [0.16396679]
# 880 0.0035028432 [0.9312605] [0.15626097]
# 900 0.0031813404 [0.934491] [0.1489173]
# 920 0.0028893452 [0.9375697] [0.14191875]
# 940 0.0026241401 [0.9405037] [0.13524906]
# 960 0.002383293 [0.9432998] [0.12889287]
# 980 0.0021645455 [0.9459645] [0.1228354]
# 1000 0.001965878 [0.9485039] [0.11706261]
# 1020 0.0017854379 [0.95092404] [0.11156111]
# 1040 0.0016215622 [0.95323044] [0.10631816]
# 1060 0.0014727293 [0.9554284] [0.10132162]
# 1080 0.0013375566 [0.9575231] [0.09655989]
# 1100 0.0012147928 [0.9595194] [0.09202196]
# 1120 0.0011032968 [0.96142185] [0.08769724]
# 1140 0.001002031 [0.96323484] [0.08357578]
# 1160 0.00091005844 [0.9649627] [0.07964801]
# 1180 0.0008265288 [0.9666093] [0.07590485]
# 1200 0.000750667 [0.9681786] [0.07233762]
# 1220 0.0006817694 [0.96967405] [0.06893803]
# 1240 0.0006191957 [0.97109926] [0.06569819]
# 1260 0.0005623607 [0.97245747] [0.06261061]
# 1280 0.0005107456 [0.97375184] [0.05966815]
# 1300 0.000463868 [0.9749855] [0.05686396]
# 1320 0.0004212899 [0.97616106] [0.05419155]
# 1340 0.00038262192 [0.9772814] [0.05164474]
# 1360 0.0003475053 [0.9783491] [0.04921762]
# 1380 0.00031561038 [0.9793665] [0.04690459]
# 1400 0.00028664086 [0.98033637] [0.04470029]
# 1420 0.00026033213 [0.9812604] [0.04259951]
# 1440 0.00023643655 [0.98214114] [0.04059746]
# 1460 0.00021473582 [0.98298043] [0.03868952]
# 1480 0.00019502778 [0.9837803] [0.03687125]
# 1500 0.00017712743 [0.98454255] [0.03513842]
# 1520 0.00016086917 [0.985269] [0.03348705]
# 1540 0.0001461048 [0.9859613] [0.03191328]
# 1560 0.00013269442 [0.986621] [0.0304135]
# 1580 0.00012051485 [0.9872498] [0.0289842]
# 1600 0.000109454384 [0.987849] [0.02762206]
# 1620 9.940727e-05 [0.98842] [0.02632393]
# 1640 9.0283305e-05 [0.9889642] [0.02508682]
# 1660 8.199818e-05 [0.98948276] [0.02390786]
# 1680 7.447226e-05 [0.98997694] [0.02278442]
# 1700 6.763613e-05 [0.99044824] [0.02171363]
# 1720 6.143007e-05 [0.99089706] [0.02069316]
# 1740 5.5790773e-05 [0.9913249] [0.01972063]
# 1760 5.0669787e-05 [0.9917326] [0.01879383]
# 1780 4.6020166e-05 [0.9921211] [0.01791059]
# 1800 4.1795003e-05 [0.99249136] [0.01706886]
# 1820 3.7959373e-05 [0.9928442] [0.01626669]
# 1840 3.4475266e-05 [0.9931805] [0.01550224]
# 1860 3.131138e-05 [0.993501] [0.01477371]
# 1880 2.8437336e-05 [0.9938064] [0.01407941]
# 1900 2.5826992e-05 [0.99409753] [0.01341774]
# 1920 2.3456692e-05 [0.9943749] [0.01278718]
# 1940 2.130365e-05 [0.9946392] [0.01218625]
# 1960 1.93484e-05 [0.99489117] [0.01161354]
# 1980 1.7572882e-05 [0.9951314] [0.0110677]
# 2000 1.5959251e-05 [0.99536014] [0.01054754]
